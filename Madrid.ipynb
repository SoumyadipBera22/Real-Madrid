# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('fifa.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df['Club'].value_counts()
# Out:
# Rayo Vallecano       33
# Southampton          33
# Atlético Madrid      33
# Manchester United    33
# FC Barcelona         33
#                      ..
# Internacional        20
# Grêmio               20
# Sligo Rovers         19
# Limerick FC          19
# Derry City           18
# Name: Club, Length: 651, dtype: int64

# %%
# Extracting the Real Madrid data
df=df[df['Club']=='Real Madrid']

# %%
df.head()
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 6            6  177003     L. Modrić   32
# 8            8  155862  Sergio Ramos   32
# 11          11  182521      T. Kroos   28
# 19          19  192119   T. Courtois   26
# 27          27  200145      Casemiro   26
#
#                                              Photo Nationality  \
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 19  https://cdn.sofifa.org/players/4/19/192119.png     Belgium
# 27  https://cdn.sofifa.org/players/4/19/200145.png      Brazil
#
#                                    Flag  Overall  Potential         Club  ...  \
# 6   https://cdn.sofifa.org/flags/10.png       91         91  Real Madrid  ...
# 8   https://cdn.sofifa.org/flags/45.png       91         91  Real Madrid  ...
# 11  https://cdn.sofifa.org/flags/21.png       90         90  Real Madrid  ...
# ...

# %%
df.reset_index(drop=True)
# Out:
#     Unnamed: 0      ID             Name  Age  \
# 0            6  177003        L. Modrić   32
# 1            8  155862     Sergio Ramos   32
# 2           11  182521         T. Kroos   28
# 3           19  192119      T. Courtois   26
# 4           27  200145         Casemiro   26
# 5           30  197781             Isco   26
# 6           35  176676          Marcelo   30
# 7           36  173731          G. Bale   28
# 8           46  193041         K. Navas   31
# 9           62  201535        R. Varane   25
# 10          79  220834    Marco Asensio   22
# 11         105  165153       K. Benzema   30
# 12         123  204963         Carvajal   26
# 13         172  208618    Lucas Vázquez   27
# 14         188  200724  Nacho Fernández   28
# 15         328  222509    Dani Ceballos   21
# 16         417  234035        Odriozola   22
# 17         430  221639          Mariano   24
# 18         573  226161  Marcos Llorente   23
# 19         697  177644     Kiko Casilla   31
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.describe(include='object')
# Out:
#                  Name                                           Photo  \
# count              33                                              33
# unique             33                                              33
# top     Manu Hernando  https://cdn.sofifa.org/players/4/19/246608.png
# freq                1                                               1
#
#        Nationality                                 Flag         Club  \
# count           33                                   33           33
# unique          11                                   11            1
# top          Spain  https://cdn.sofifa.org/flags/45.png  Real Madrid
# freq            19                                   19           33
#
#                                            Club Logo  Value Wage  \
# count                                             33     33   33
# unique                                             1     30   27
# top     https://cdn.sofifa.org/teams/2/light/243.png  €1.2M  €9K
# ...

# %%
sns.countplot(x='Preferred Foot',data=df)
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='count'>

# %%
sns.countplot(x='Work Rate',data=df)
# Out:
# <AxesSubplot:xlabel='Work Rate', ylabel='count'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
col_drop=['ID','Photo','Flag','Club','Club Logo']
df.drop(col_drop,axis=1,inplace=True)

# %%
df1=df.copy()

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
# ...

# %%
df1['Nationality']
# Out:
# 6                   Croatia
# 8                     Spain
# 11                  Germany
# 19                  Belgium
# 27                   Brazil
# 30                    Spain
# 35                   Brazil
# 36                    Wales
# 46               Costa Rica
# 62                   France
# 79                    Spain
# 105                  France
# 123                   Spain
# 172                   Spain
# 188                   Spain
# 328                   Spain
# 417                   Spain
# 430      Dominican Republic
# 573                   Spain
# 697                   Spain
# 754                   Spain
# 1143                 Brazil
# 2513                Uruguay
# 6724                  Spain
# 8732                  Spain
# 9141                  Spain
# 10178             Argentina
# 10269                 Spain
# 11163                 Spain
# 11327                 Spain
# 11877                 Spain
# 12504                 Spain
# 13687                France
# ...

# %%
df1.head()
# Out:
#             Name  Age Nationality  Overall  Potential   Value   Wage  Special  \
# 6      L. Modrić   32     Croatia       91         91    €67M  €420K     2280
# 8   Sergio Ramos   32       Spain       91         91    €51M  €380K     2201
# 11      T. Kroos   28     Germany       90         90  €76.5M  €355K     2190
# 19   T. Courtois   26     Belgium       89         90  €53.5M  €240K     1311
# 27      Casemiro   26      Brazil       88         90  €59.5M  €285K     2170
#
#    Preferred Foot  International Reputation  ...  Composure  Marking  \
# 6           Right                       4.0  ...       84.0     60.0
# 8           Right                       4.0  ...       82.0     87.0
# 11          Right                       4.0  ...       85.0     72.0
# 19           Left                       4.0  ...       66.0     20.0
# 27          Right                       3.0  ...       84.0     88.0
#
#    StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# ...

# %%
df1.reset_index(drop=True)
# Out:
#                Name  Age         Nationality  Overall  Potential   Value  \
# 0         L. Modrić   32             Croatia       91         91    €67M
# 1      Sergio Ramos   32               Spain       91         91    €51M
# 2          T. Kroos   28             Germany       90         90  €76.5M
# 3       T. Courtois   26             Belgium       89         90  €53.5M
# 4          Casemiro   26              Brazil       88         90  €59.5M
# 5              Isco   26               Spain       88         91  €73.5M
# 6           Marcelo   30              Brazil       88         88    €43M
# 7           G. Bale   28               Wales       88         88    €60M
# 8          K. Navas   31          Costa Rica       87         87  €30.5M
# 9         R. Varane   25              France       86         91    €50M
# 10    Marco Asensio   22               Spain       85         92    €54M
# 11       K. Benzema   30              France       85         85    €37M
# ...

# %% [markdown]
# ### Binning the players are Starting 11 material, subs, and reserve

# %%
df1['Starting11']=''

# %%
df1.loc[df1['Overall']>=80,'Starting11']="Starting 11"
df1.loc[df1['Overall']<80,'Starting11']="Reserve"

# %%
df1.head()
# Out:
#             Name  Age Nationality  Overall  Potential   Value   Wage  Special  \
# 6      L. Modrić   32     Croatia       91         91    €67M  €420K     2280
# 8   Sergio Ramos   32       Spain       91         91    €51M  €380K     2201
# 11      T. Kroos   28     Germany       90         90  €76.5M  €355K     2190
# 19   T. Courtois   26     Belgium       89         90  €53.5M  €240K     1311
# 27      Casemiro   26      Brazil       88         90  €59.5M  €285K     2170
#
#    Preferred Foot  International Reputation  ...  Marking  StandingTackle  \
# 6           Right                       4.0  ...     60.0            76.0
# 8           Right                       4.0  ...     87.0            92.0
# 11          Right                       4.0  ...     72.0            79.0
# 19           Left                       4.0  ...     20.0            18.0
# 27          Right                       3.0  ...     88.0            90.0
#
# ...

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1.head(9)
# Out:
#            Name  Age Nationality  Overall  Potential   Value   Wage  Special  \
# 0     L. Modrić   32     Croatia       91         91    €67M  €420K     2280
# 1  Sergio Ramos   32       Spain       91         91    €51M  €380K     2201
# 2      T. Kroos   28     Germany       90         90  €76.5M  €355K     2190
# 3   T. Courtois   26     Belgium       89         90  €53.5M  €240K     1311
# 4      Casemiro   26      Brazil       88         90  €59.5M  €285K     2170
# 5          Isco   26       Spain       88         91  €73.5M  €315K     2137
# 6       Marcelo   30      Brazil       88         88    €43M  €285K     2279
# 7       G. Bale   28       Wales       88         88    €60M  €355K     2279
# 8      K. Navas   31  Costa Rica       87         87  €30.5M  €195K     1345
#
#   Preferred Foot  International Reputation  ...  Marking  StandingTackle  \
# 0          Right                       4.0  ...     60.0            76.0
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
# ...

# %%
df1.drop('Real Face',axis=1,inplace=True)

# %%
df1[['Overall','Potential']]
# Out:
#     Overall  Potential
# 0        91         91
# 1        91         91
# 2        90         90
# 3        89         90
# 4        88         90
# 5        88         91
# 6        88         88
# 7        88         88
# 8        87         87
# 9        86         91
# 10       85         92
# 11       85         85
# 12       84         87
# 13       83         83
# 14       83         85
# 15       81         88
# 16       80         88
# 17       80         85
# 18       79         87
# 19       79         79
# 20       78         86
# 21       77         92
# 22       74         84
# 23       68         80
# 24       67         79
# 25       66         78
# 26       65         80
# 27       65         75
# 28       64         80
# 29       64         79
# 30       64         76
# 31       63         77
# 32       62         71

# %%
for i in range(len(df1)):
    if ((df1['Overall'][i]<80) and (df1['Potential'][i]>=80)):
        df1['Starting11'][i]='Sub'
# Out:
# <ipython-input-30-c413a2d24dc6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Starting11'][i]='Sub'

# %%
df1['Starting11'].value_counts()
# Out:
# Starting 11    18
# Reserve         8
# Sub             7
# Name: Starting11, dtype: int64

# %%
sns.barplot(x='Starting11',y='Overall',data=df1)
# Out:
# <AxesSubplot:xlabel='Starting11', ylabel='Overall'>

# %% [markdown]
# ### Binning the players into 3 broad categories - Attack, Midfield, Defense

# %%
df1['AttackPotential']=''
df1['MidfieldPotential']=''
df1['DefensePotential']=''
df1['GKPotential']=''

# %%
strikecol=['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW']
att=[]
for i in strikecol:
    att.append(int(df1[i][5][:2]))

# %%
att
# Out:
# [76, 76, 76, 84, 83, 83, 83, 84]

# %%
import statistics as st

# %%
st.median(att)
# Out:
# 83.0

# %%
att=[]

# %%
for i in range(len(df1)):
    for j in strikecol:
        att.append((df1[j][i]))
    print(att)
    att=[]
# Out:
# ['77+3', '77+3', '77+3', '85+3', '84+3', '84+3', '84+3', '85+3']
# ['73+3', '73+3', '73+3', '70+3', '71+3', '71+3', '71+3', '70+3']
# ['78+3', '78+3', '78+3', '81+3', '82+3', '82+3', '82+3', '81+3']
# [nan, nan, nan, nan, nan, nan, nan, nan]
# ['72+3', '72+3', '72+3', '69+3', '73+3', '73+3', '73+3', '69+3']
# ['76+3', '76+3', '76+3', '84+3', '83+3', '83+3', '83+3', '84+3']
# ['80+3', '80+3', '80+3', '84+3', '83+3', '83+3', '83+3', '84+3']
# ['86+3', '86+3', '86+3', '86+3', '86+3', '86+3', '86+3', '86+3']
# [nan, nan, nan, nan, nan, nan, nan, nan]
# ['62+3', '62+3', '62+3', '61+3', '63+3', '63+3', '63+3', '61+3']
# ['79+3', '79+3', '79+3', '83+3', '83+3', '83+3', '83+3', '83+3']
# ['81+3', '81+3', '81+3', '81+3', '82+3', '82+3', '82+3', '81+3']
# ['65+3', '65+3', '65+3', '71+3', '68+3', '68+3', '68+3', '71+3']
# ['75+2', '75+2', '75+2', '81+2', '80+2', '80+2', '80+2', '81+2']
# ['58+2', '58+2', '58+2', '61+2', '59+2', '59+2', '59+2', '61+2']
# ...

# %%
type((df1['LW'][5][:2]))
# Out:
# str

# %%
midcol=['LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM','LDM','CDM', 'RDM']

# %%
mid=[]

# %%
for i in range(len(df1)):
    for j in midcol:
        mid.append((df1[j][i]))
    print(mid)
    mid=[]
# Out:
# ['87+3', '87+3', '87+3', '86+3', '88+3', '88+3', '88+3', '86+3', '81+3', '81+3', '81+3']
# ['71+3', '71+3', '71+3', '72+3', '75+3', '75+3', '75+3', '72+3', '84+3', '84+3', '84+3']
# ['84+3', '84+3', '84+3', '82+3', '86+3', '86+3', '86+3', '82+3', '82+3', '82+3', '82+3']
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# ['74+3', '74+3', '74+3', '71+3', '80+3', '80+3', '80+3', '71+3', '85+3', '85+3', '85+3']
# ['86+3', '86+3', '86+3', '83+3', '83+3', '83+3', '83+3', '83+3', '73+3', '73+3', '73+3']
# ['84+3', '84+3', '84+3', '85+3', '84+3', '84+3', '84+3', '85+3', '83+3', '83+3', '83+3']
# ['85+3', '85+3', '85+3', '85+3', '80+3', '80+3', '80+3', '85+3', '70+3', '70+3', '70+3']
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# ['64+3', '64+3', '64+3', '64+3', '69+3', '69+3', '69+3', '64+3', '79+3', '79+3', '79+3']
# ['83+3', '83+3', '83+3', '83+3', '79+3', '79+3', '79+3', '83+3', '63+3', '63+3', '63+3']
# ...

# %%
defcol=['RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB','LWB']
defe=[]
for i in range(len(df1)):
    for j in defcol:
        defe.append((df1[j][i]))
    print(defe)
    defe=[]
# Out:
# ['82+3', '79+3', '71+3', '71+3', '71+3', '79+3', '82+3']
# ['81+3', '84+3', '87+3', '87+3', '87+3', '84+3', '81+3']
# ['79+3', '77+3', '72+3', '72+3', '72+3', '77+3', '79+3']
# [nan, nan, nan, nan, nan, nan, nan]
# ['78+3', '79+3', '85+3', '85+3', '85+3', '79+3', '78+3']
# ['72+3', '68+3', '63+3', '63+3', '63+3', '68+3', '72+3']
# ['85+3', '84+3', '81+3', '81+3', '81+3', '84+3', '85+3']
# ['73+3', '71+3', '67+3', '67+3', '67+3', '71+3', '73+3']
# [nan, nan, nan, nan, nan, nan, nan]
# ['75+3', '78+3', '83+3', '83+3', '83+3', '78+3', '75+3']
# ['66+3', '62+3', '51+3', '51+3', '51+3', '62+3', '66+3']
# ['57+3', '53+3', '49+3', '49+3', '49+3', '53+3', '57+3']
# ['82+3', '82+3', '80+3', '80+3', '80+3', '82+3', '82+3']
# ['69+2', '65+2', '55+2', '55+2', '55+2', '65+2', '69+2']
# ['77+2', '79+2', '80+2', '80+2', '80+2', '79+2', '77+2']
# ['75+2', '73+2', '68+2', '68+2', '68+2', '73+2', '75+2']
# ['78+2', '78+2', '75+2', '75+2', '75+2', '78+2', '78+2']
# ...

# %%
df1['Position']
# Out:
# 0     RCM
# 1     RCB
# 2     LCM
# 3      GK
# 4     CDM
# 5      LW
# 6      LB
# 7      ST
# 8      GK
# 9     RCB
# 10     RW
# 11     ST
# 12     RB
# 13     RW
# 14     CB
# 15    LCM
# 16     RB
# 17     ST
# 18    CDM
# 19     GK
# 20     CB
# 21     LW
# 22     CM
# 23     LB
# 24     CB
# 25     ST
# 26     LW
# 27     CM
# 28     RB
# 29     LB
# 30     CB
# 31     ST
# 32     GK
# Name: Position, dtype: object

# %%
gk_df=df1[df1['Position']=='GK']

# %%
gk_df
# Out:
#             Name  Age Nationality  Overall  Potential   Value   Wage  Special  \
# 3    T. Courtois   26     Belgium       89         90  €53.5M  €240K     1311
# 8       K. Navas   31  Costa Rica       87         87  €30.5M  €195K     1345
# 19  Kiko Casilla   31       Spain       79         79   €7.5M  €105K     1279
# 32     L. Zidane   20      France       62         71   €350K    €9K      944
#
#    Preferred Foot  International Reputation  ...  GKHandling  GKKicking  \
# 3            Left                       4.0  ...        91.0       72.0
# 8           Right                       3.0  ...        81.0       75.0
# 19          Right                       2.0  ...        81.0       79.0
# 32          Right                       1.0  ...        60.0       61.0
#
#    GKPositioning GKReflexes Release Clause   Starting11 AttackPotential  \
# 3           86.0       88.0        €113.7M  Starting 11
# 8           82.0       90.0         €62.5M  Starting 11
# ...

# %%
df1=df1[df1['Position']!='GK'].reset_index()

# %%
df1.shape
# Out:
# (29, 88)

# %%
df1.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  GKHandling  GKKicking  GKPositioning  \
# 0     2280          Right  ...         9.0        7.0           14.0
# 1     2201          Right  ...         8.0        9.0            7.0
# 2     2190          Right  ...        11.0       13.0            7.0
# 3     2170          Right  ...        14.0       16.0           12.0
# 4     2137          Right  ...         8.0       12.0           15.0
#
#   GKReflexes Release Clause   Starting11  AttackPotential MidfieldPotential  \
# ...

# %%
att=[]
for i in range(len(df1)):
    for j in strikecol:
        att.append(int(df1[j][i][:2]))
    df1['AttackPotential'][i]=st.median(att)
    att=[]
# Out:
# <ipython-input-51-bae0bc54b374>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['AttackPotential'][i]=st.median(att)

# %%
df1.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  GKHandling  GKKicking  GKPositioning  \
# 0     2280          Right  ...         9.0        7.0           14.0
# 1     2201          Right  ...         8.0        9.0            7.0
# 2     2190          Right  ...        11.0       13.0            7.0
# 3     2170          Right  ...        14.0       16.0           12.0
# 4     2137          Right  ...         8.0       12.0           15.0
#
#   GKReflexes Release Clause   Starting11  AttackPotential MidfieldPotential  \
# ...

# %%
for i in range(len(df1)):
    for j in midcol:
        mid.append(int(df1[j][i][:2]))
    df1['MidfieldPotential'][i]=st.median(mid)
    mid=[]
# Out:
# <ipython-input-53-fb133f5d96cd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MidfieldPotential'][i]=st.median(mid)

# %%
df1.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  GKHandling  GKKicking  GKPositioning  \
# 0     2280          Right  ...         9.0        7.0           14.0
# 1     2201          Right  ...         8.0        9.0            7.0
# 2     2190          Right  ...        11.0       13.0            7.0
# 3     2170          Right  ...        14.0       16.0           12.0
# 4     2137          Right  ...         8.0       12.0           15.0
#
#   GKReflexes Release Clause   Starting11  AttackPotential MidfieldPotential  \
# ...

# %%
defcol=['RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB','LWB']
defe=[]
for i in range(len(df1)):
    for j in defcol:
        defe.append(int(df1[j][i][:2]))
    df1['DefensePotential'][i]=st.median(defe)
    defe=[]
# Out:
# <ipython-input-55-aed6359f83bd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DefensePotential'][i]=st.median(defe)

# %%
df1.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  GKHandling  GKKicking  GKPositioning  \
# 0     2280          Right  ...         9.0        7.0           14.0
# 1     2201          Right  ...         8.0        9.0            7.0
# 2     2190          Right  ...        11.0       13.0            7.0
# 3     2170          Right  ...        14.0       16.0           12.0
# 4     2137          Right  ...         8.0       12.0           15.0
#
#   GKReflexes Release Clause   Starting11  AttackPotential MidfieldPotential  \
# ...

# %%
df2=df1.copy()

# %%
df2.drop(['RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB','LWB','LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM','LDM','CDM', 'RDM','LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW','GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  Composure  Marking  StandingTackle  \
# 0     2280          Right  ...       84.0     60.0            76.0
# 1     2201          Right  ...       82.0     87.0            92.0
# 2     2190          Right  ...       85.0     72.0            79.0
# 3     2170          Right  ...       84.0     88.0            90.0
# 4     2137          Right  ...       86.0     60.0            64.0
#
#   SlidingTackle Release Clause   Starting11  AttackPotential  \
# ...

# %%
df2.drop('GKPotential',axis=1,inplace=True)

# %%
df2.head()
# Out:
#    index          Name  Age Nationality  Overall  Potential   Value   Wage  \
# 0      0     L. Modrić   32     Croatia       91         91    €67M  €420K
# 1      1  Sergio Ramos   32       Spain       91         91    €51M  €380K
# 2      2      T. Kroos   28     Germany       90         90  €76.5M  €355K
# 3      4      Casemiro   26      Brazil       88         90  €59.5M  €285K
# 4      5          Isco   26       Spain       88         91  €73.5M  €315K
#
#    Special Preferred Foot  ...  Penalties  Composure  Marking StandingTackle  \
# 0     2280          Right  ...       82.0       84.0     60.0           76.0
# 1     2201          Right  ...       75.0       82.0     87.0           92.0
# 2     2190          Right  ...       73.0       85.0     72.0           79.0
# 3     2170          Right  ...       66.0       84.0     88.0           90.0
# 4     2137          Right  ...       76.0       86.0     60.0           64.0
#
# ...

# %%
df2['MidfieldPotential'].describe()
# Out:
# count     29
# unique    23
# top       80
# freq       3
# Name: MidfieldPotential, dtype: int64

# %%
max(['54','54'])
# Out:
# '54'

# %%
max([df2['AttackPotential'][0],df2['MidfieldPotential'][0],df2['DefensePotential'][0]])
# Out:
# 87

# %%
new_df=df2[['AttackPotential','MidfieldPotential','DefensePotential']]

# %%
new_df.head()
# Out:
#   AttackPotential MidfieldPotential DefensePotential
# 0            84.0                87               79
# 1            71.0                75               84
# 2            81.0                84               77
# 3            72.0                80               79
# 4            83.0                83               68

# %%
col_names=list(new_df.columns)

# %%
for i in col_names:
    new_df[i]=new_df[i].astype('int')
# Out:
# <ipython-input-68-c1a7613a51cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[i]=new_df[i].astype('int')

# %%
new_df['D']=new_df.apply(lambda x:x.idxmax(),axis=1)
# Out:
# <ipython-input-69-5a933e50436d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['D']=new_df.apply(lambda x:x.idxmax(),axis=1)

# %%
new_df['D']
# Out:
# 0     MidfieldPotential
# 1      DefensePotential
# 2     MidfieldPotential
# 3     MidfieldPotential
# 4       AttackPotential
# 5     MidfieldPotential
# 6       AttackPotential
# 7      DefensePotential
# 8       AttackPotential
# 9       AttackPotential
# 10     DefensePotential
# 11      AttackPotential
# 12     DefensePotential
# 13    MidfieldPotential
# 14     DefensePotential
# 15      AttackPotential
# 16    MidfieldPotential
# 17     DefensePotential
# 18      AttackPotential
# 19    MidfieldPotential
# 20     DefensePotential
# 21     DefensePotential
# 22      AttackPotential
# 23      AttackPotential
# 24    MidfieldPotential
# 25     DefensePotential
# 26     DefensePotential
# 27     DefensePotential
# 28      AttackPotential
# Name: D, dtype: object

# %%
df2['Position_Class']=new_df['D']

# %%
for i in range(len(df2)):
    df2['Position_Class'][i]=df2['Position_Class'][i][:-9]
# Out:
# <ipython-input-72-6d205efbd0fc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Position_Class'][i]=df2['Position_Class'][i][:-9]

# %%
df2[['Name','Position_Class']]
# Out:
#                Name Position_Class
# 0         L. Modrić       Midfield
# 1      Sergio Ramos        Defense
# 2          T. Kroos       Midfield
# 3          Casemiro       Midfield
# 4              Isco         Attack
# 5           Marcelo       Midfield
# 6           G. Bale         Attack
# 7         R. Varane        Defense
# 8     Marco Asensio         Attack
# 9        K. Benzema         Attack
# 10         Carvajal        Defense
# 11    Lucas Vázquez         Attack
# 12  Nacho Fernández        Defense
# 13    Dani Ceballos       Midfield
# 14        Odriozola        Defense
# 15          Mariano         Attack
# 16  Marcos Llorente       Midfield
# 17          Vallejo        Defense
# 18  Vinícius Júnior         Attack
# 19      F. Valverde       Midfield
# 20         Reguilón        Defense
# 21     Javi Sánchez        Defense
# 22  Cristo González         Attack
# 23  F. Feuillassier         Attack
# 24          Fidalgo       Midfield
# 25     Sergio López        Defense
# ...

# %%
sns.countplot('Position_Class',data=df2)
# Out:
# C:\Users\SOUMYADIP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Position_Class', ylabel='count'>

# %%
df2.columns
# Out:
# Index(['index', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'Release Clause', 'Starting11', 'AttackPotential', 'MidfieldPotential',
#        'DefensePotential', 'Position_Class'],
#       dtype='object')

# %%
df2['Weak Foot']
# Out:
# 0     4.0
# 1     3.0
# 2     5.0
# 3     3.0
# 4     3.0
# 5     4.0
# 6     3.0
# 7     3.0
# 8     3.0
# 9     4.0
# 10    3.0
# 11    4.0
# 12    4.0
# 13    3.0
# 14    3.0
# 15    4.0
# 16    3.0
# 17    3.0
# 18    4.0
# 19    3.0
# 20    3.0
# 21    3.0
# 22    2.0
# 23    4.0
# 24    3.0
# 25    3.0
# 26    3.0
# 27    3.0
# 28    3.0
# Name: Weak Foot, dtype: float64

# %% [markdown]
# ### Weak Foot wrt Preferred Foot

# %%
sns.countplot(x='Weak Foot',hue='Preferred Foot',data=df2)
# Out:
# <AxesSubplot:xlabel='Weak Foot', ylabel='count'>

# %%
pd.crosstab(df2['Weak Foot'],df2['Preferred Foot'],normalize='index').round(4)*100
# Out:
# Preferred Foot   Left   Right
# Weak Foot
# 2.0              0.00  100.00
# 3.0             21.05   78.95
# 4.0             12.50   87.50
# 5.0              0.00  100.00

# %%
#plot Size
plt.figure(figsize=(32,6))
#plot title
plt.title("Age")
sns.barplot(x=df2["Name"], y=df2["Age"])
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Name', ylabel='Age'>

# %%
#plot Size
plt.figure(figsize=(32,6))
#plot title
plt.title("Players with highest ratings")
sns.barplot(x=df2["Name"], y=df2["Overall"])
# Out:
# <AxesSubplot:title={'center':'Players with highest ratings'}, xlabel='Name', ylabel='Overall'>

# %%
#plot Size
plt.figure(figsize=(32,6))
#plot title
plt.title("LongPassing")
sns.barplot(x=df2["Name"], y=df2["LongPassing"])
# Out:
# <AxesSubplot:title={'center':'LongPassing'}, xlabel='Name', ylabel='LongPassing'>

# %%
#plot Size
plt.figure(figsize=(33,6))
#plot title
plt.title("Finishing")
sns.barplot(x=df2["Name"], y=df2["Finishing"])
# Out:
# <AxesSubplot:title={'center':'Finishing'}, xlabel='Name', ylabel='Finishing'>
